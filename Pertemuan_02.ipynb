# %% [markdown]
# # Pertemuan 02 - Struktur Data Python, NumPy & Pandas
#
# Nama: Athaya Zatus Shawary Lathief
# NIM: 250401020181

# %%
import numpy as np

angka = np.array([10, 20, 30, 40, 50])

print("Jumlah:", np.sum(angka))
print("Rata-rata:", np.mean(angka))
print("Nilai Maksimum:", np.max(angka))
# Out:
# Jumlah: 150
# Rata-rata: 30.0
# Nilai Maksimum: 50

# %%
import pandas as pd

data = {
    "Nama": ["Andi", "Budi", "Citra"],
    "Usia": [20, 21, 19]
}

df = pd.DataFrame(data)
df
# Out:
#     Nama  Usia
# 0   Andi    20
# 1   Budi    21
# 2  Citra    19

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari struktur data Python, NumPy, dan Pandas untuk mengelola data secara lebih efisien.
